# %% [markdown]
# # Covariance Vs Correlation coefficients and their significance
#
# Previously, we had covered the **[Basics of Statistics](https://github.com/nikitaprasad21/Statistics-Cheatcode/blob/main/statistics.ipynb)**.
#
#
# # Covariance
#
# It is a statistical measure that describes the degree to which two numerical variables are linearly related.

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ### Why Covariance, if we have Variance?
#
#
# There, we discussed about `Variance`, a statistical measure which is not the true representation of spread.
#
#  It provides insights into the variability of individual variables but does not capture the relationship between multiple variables.
#
#  In other words, it doesn't quantifies the extent to which changes in one variable are associated with changes in another variable.
#
#  ### What problem does Covariance solve?
#
# Covariance helps assess the nature and strength of the relationship between two variables. It indicates whether changes in one variable are positively or negatively associated with changes in another variable.
#
# Covariance is a key input in predictive modeling and regression analysis. It helps modelers understand the interdependence between predictor variables and the target variable, enabling the development of accurate predictive models.

# %% [markdown]
# ![5.png](attachment:5.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create a DataFrame with two columns 'x' and 'y'
data = {
    'x': [12,45,68,42,103],
    'y': [11,29,58,121,100]
}

df = pd.DataFrame(data)

# %%
# Calculate the covariance between columns 'x' and 'y'
covariance = df['x'].cov(df['y'])

print("Covariance between 'x' and 'y':", covariance)
# Out:
# Covariance between 'x' and 'y': 884.25

# %%
# Create subplots with only one axis
fig, ax1 = plt.subplots(1, 1, figsize=(10, 3))

# Plot scatterplot on ax1
ax1.scatter(df['x'], df['y'])

# Set title with covariance value
ax1.set_title("Covariance - " + str(np.cov(df['x'], df['y'])[0, 1]))

# Show the plot
plt.show()

# %% [markdown]
# ### Limitation of Covariance
#
# It does not tell us about the `strength of the relationship` between two variables, causing the `magnitude of covariance` is affected by the `scale of the variables`.

# %%
# Original data covariance
cov_original = np.cov(df['x'], df['y'])[0, 1]
print("Covariance of original data:", cov_original)

# Here, [0, 1] refers to the element at the first row (index 0) and the second column (index 1) of the covariance matrix, which corresponds to the covariance between variable x and variable y.

# Data where each variable is multiplied by 2 covariance
cov_scaled = np.cov(df['x'] * 2, df['y'] * 2)[0, 1]
print("Covariance of scaled data (each variable multiplied by 2):", cov_scaled)

# Comment explaining the difference
print("\nWhen each variable is multiplied by 2, the covariance is also scaled by a factor of 4.")
# Out:
# Covariance of original data: 884.25
# Covariance of scaled data (each variable multiplied by 2): 3537.0
#
# When each variable is multiplied by 2, the covariance is also scaled by a factor of 4.

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 3))

# Plot scatterplots on each axes

# Scatterplot of variable x against itself
ax[0].scatter(df['x'], df['x'])
# Scatterplot of variable x against variable y
ax[1].scatter(df['x'], df['y'])
# Scatterplot of variable x multiplied by 2 against variable y multiplied by 2
ax[2].scatter(df['x']*2, df['y']*2)

ax[0].set_title("Covariance - " + str(np.cov(df['x'],df['x'])[0,1]))
ax[1].set_title("Covariance - " + str(np.cov(df['x'],df['y'])[0,1]))
ax[2].set_title("Covariance - " + str(np.cov(df['x']*2,df['y']*2)[0,1]))

# Show the plot
plt.show()

# %% [markdown]
# It is fairly proven that by just `multiplying with 2`, the covariance variance has increased `fourfold`.
#
# This not appreciated, as Covariance is not normalized which means it does not have a bounded range. Therefore, it is `not suitable for comparing the strength of relationships` across different datasets or variables.

# %% [markdown]
# ### Disadvantages of Covariance
#
# * **Directionality**: Covariance only measures the direction of the relationship between variables (positive or negative), but it does not quantify the strength of the relationship. As a result, covariance alone may not provide sufficient information to assess the degree of association between variables accurately. Since the magnitude of covariance is affected by the
# scale of the variables.
#
# * **Outliers**: Covariance is sensitive to outliers in the data. Extreme values can disproportionately influence the covariance calculation, leading to biased estimates of the relationship between variables. This can result in misleading conclusions about the strength and direction of the relationship.
#
# * **Independence Assumption**: Covariance assumes that variables are linearly related and that their relationship is stationary over time. In practice, variables may exhibit non-linear relationships or time-varying dependencies, which covariance may not capture accurately.
#
# * **Not Normalized**: Covariance is not normalized and does not have a bounded range. Therefore, it is not suitable for comparing the strength of relationships across different datasets or variables. Normalized measures such as correlation coefficients are often preferred for this purpose.

# %% [markdown]
# ## What is the Cov(variable) with itself?
#
# If you have noticed in the above code, it is mentioned that the scatterplot of variable x against itself and covariance is also calculated btw variable x and itself, ultimately represent the `variance of x`.

# %% [markdown]
# # Correlation
#
# It is a statistical measure that quantifies the strength and direction of the linear relationship between two variables.
#
# Basically, it measures the degree to which two variables are related and how they tend to change together, using given below formula.
#
# #### Pearson Correlation Coefficient Formula:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Correlation values range from -1 to 1, where:
#
# * A `correlation coefficient of 1` indicates a `perfect positive linear relationship`, meaning that as one variable increases, the other variable also increases proportionally.
# * A `correlation coefficient of -1` indicates a `perfect negative linear relationship`, meaning that as one variable increases, the other variable decreases proportionally.
# * A `correlation coefficient of 0` indicates `no linear relationship` between the variables.
#
# Further, it can also measure the `strong or weak or non linear correlation` among the variables.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Create subplots with two axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))

# Plot scatterplots on each axes
ax1.scatter(df['x'], df['x'])  # Scatterplot of variable 'x' against itself
ax2.scatter(df['x'], df['y'])  # Scatterplot of variable 'x' against variable 'y'

# Set titles with correlation coefficients
ax1.set_title("Correlation - " + str(df['x'].corr(df['x'])))
ax2.set_title("Correlation - " + str(df['x'].corr(df['y'])))
# Out:
# Text(0.5, 1.0, 'Correlation - 0.5627239959270611')

# %% [markdown]
# * The correlation of a variable with itself is always 1, as it represents the perfect positive linear relationship.
#
# * The correlation between variables 'x' and 'y' represents the strength and direction of their linear relationship.

# %% [markdown]
# ### Most importantly it doesn't depend on the scale of data.
#
# Let's prove!

# %%
# Create subplots with two axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))

# Plot scatterplots on each axes
ax1.scatter(df['x'], df['y'])         # Scatterplot of 'x' against 'y'
ax2.scatter(df['x']*2, df['y'])  # Scatterplot of 'x' multiplied by 2 against 'y'

# Set titles with correlation coefficients
ax1.set_title("Correlation - " + str(df['x'].corr(df['y'])))
ax2.set_title("Correlation - " + str((df['x']*2).corr(df['y']*2)))
# Out:
# Text(0.5, 1.0, 'Correlation - 0.5627239959270611')

# %% [markdown]
# * The correlation between 'x' and 'y' represents the strength and direction of their linear relationship.
# * The correlation between 'x' multiplied by 2 and 'y' remains the same as the original correlation,
# * As scaling the variables does not change the linear relationship between them.

# %% [markdown]
# ## How to measure `Non-Linear Correlation` among variables?
#
# The Pearson correlation coefficient, which is the most commonly used measure of correlation, quantifies the strength and direction of the linear relationship between two variables.
#
# However, it is important to note that the Pearson correlation coefficient may still capture some aspects of non-linear relationships, especially if the non-linearity is mild.
#
# If the relationship between variables is non-linear, alternative measures of correlation may be more appropriate such as :
#
# * **Spearman's Rank Correlation**: Spearman's correlation coefficient assesses the strength and direction of the monotonic relationship between two variables, regardless of whether the relationship is linear or non-linear. It is based on the ranks of the data rather than the actual values and is often used when the relationship between variables is non-linear or the data is ordinal.
# * **Kendall's Tau**: It is another non-parametric measure of correlation that assesses the ordinal association between two variables. It is robust to non-linear relationships and outliers and is often used when the data is ordinal or the relationship is non-linear.
# * **Non-Parametric Correlation**: There are also other non-parametric measures of correlation that can capture non-linear relationships, such as the `distance correlation` or the `maximal information coefficient (MIC)`. These measures do not assume a specific functional form for the relationship between variables and can capture complex non-linear dependencies.

# %% [markdown]
# # Correlation Doesn't Implies Causation!
#
# I know you have heard this statement many a times, but would be confused between the two terms (as they are confusing).
#
# For this, I'll show you 5 different examples after that you may not face any confusion around the topic.
#
# #### EXAMPLE 1:
#
# If your laptop is running out of battery, it will definitely lead to either shutting off the laptop, and hence whatever video you are watching may not be working. This means the two situations are correlated, but the cause was running out of battery.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### EXAMPLE 2:
#
# There is a correlation seen between phone freezing and text messages not working. But are they causing each other?
#
# No!
#
# The cause is the lack of memory.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### EXAMPLE 3:
#
#
# A research was conducted by a famous organization, and they found that there is a high positive correlation between sunburn and an increase in ice cream sales.
#
# What do you think? Are they responsible for causing each other?
#
# I hope you guess the answer, NO!
#
# It's the hot weather that is separately causing the two events.
#
# By chance, they are correlated but not causing each other.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Example 4:
#
# A product manager noticed the positive correlation between cart abandonment and a large number of uninstalls of its e-commerce app.
#
# He contacted a data scientist to understand whether they are actually causing each other or just a correlation.
#
# Through extensive analysis, it was concluded that due to the bad user experience caused by too many steps in purchasing a product, it is leading to the two events.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Correlation
#
# When things are correlated, we observe a relationship between them but we can’t say for sure that one causes the other.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let’s take a closer look at what causation, correlation, and contribution actually are. Then we’ll explore how to apply it to what’s happening in your business.
#
# ## Causation
#
# When two phenomena have a causal relationship, it means that X thing causes Y thing.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Example 5:
#
# Let's say you work for an e-commerce company, and your goal is to increase sales by optimizing online advertising strategies.
#
# You have data on daily advertising spending (in dollars) and daily sales revenue (in dollars) for the past year.
#
# ### Correlation:
#
# You start by analyzing the correlation between daily advertising spending and daily sales revenue.
#
# After calculating the correlation coefficient, you find a strong positive correlation between the two variables, indicating that days with higher advertising spending tend to have higher sales revenue.
#
# This correlation suggests an association between advertising spending and sales but does not imply causation.
#
#
# ### Causation:
#
# To determine whether advertising spending directly causes an increase in sales revenue, you decide to conduct a controlled experiment.
#
#
#
#
# You randomly select a group of customers and expose them to an advertising campaign while keeping another group as a control group with no exposure to the campaign. After the campaign, you compare the sales revenue between the exposed group and the control group.
#
# If the exposed group shows a significant increase in sales revenue compared to the control group, you may conclude that the advertising campaign caused the increase in sales. *This establishes a causal relationship between advertising spending and sales revenue.*
#
# However, if there is no significant difference in sales revenue between the exposed group and the control group, you cannot conclude that the advertising campaign caused the increase in sales.
#
#  Other factors may be influencing sales, and the correlation observed earlier may be due to confounding variables.

# %% [markdown]
# ***Correlation is a far more common relationship between 2 variables than causation.***

# %% [markdown]
# ## Most Important
#
# In data science, while corr() can provide you with valuable insights on how different variables are related, it cannot be used to establish the causality among the events.
#
#
# Establishing causality often rewuire additional evidence achieved throgh experiments, random controlled trial (A/B tests), well designed surveys, observational studies, domain knowledge and other statistical measures.

# %% [markdown]
# ### Pearson’s Correlation Coefficient
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > Stay tuned for other Probability and Don't forget to **Star** this Github Repository for more such contents and consider **sharing with others**.
